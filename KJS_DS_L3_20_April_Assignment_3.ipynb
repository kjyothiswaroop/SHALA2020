# %% [markdown]
# <a href="https://colab.research.google.com/github/kjyothiswaroop/SHALA2020/blob/master/KJS_DS_L3_20_April_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment - 3: Improving Graphs**
#
# ---
# Course website: [SHALA-2020](https://shala2020.github.io/)
#
# This assignment will get you familiarized with improving plots/graphs in Python.

# %% [markdown]
# ---
# ## Part 1 - Importing packages and loading data
# ---

# %% [markdown]
# ###Import the following libraries:
#
# * ```numpy``` with an alias name ```np```,
# * ```pandas``` with an alias name ```pd```,
# * ```matplotlib.pyplot``` with an alias name ```plt```, and
# * ```seaborn``` with an alias name ```sns```.
#
# *You are free to use any other popular libraries*.

# %%
# Load the libraries with their aliases 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Using the files ```train.csv``` and ```moviesData.csv```,  peform the following:
#
# * Load these file as ```pandas``` dataframes and store it in variables named ```train``` and ```movies``` respectively.
# * Print the first ten rows of ```train``` and last ten rows of ```movies```.

# %%
# Load train.csv and movies.csv 
url_train = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Assignments/DataScience/L2/train.csv"
train = pd.read_csv(url_train)

# Print the first ten rows of train
train.head(10)
# Out:
#    Age  Attrition  ... YearsWithCurrManager  ID
# 0   41          1  ...                    5   0
# 1   49          0  ...                    7   1
# 2   37          1  ...                    0   2
# 3   33          0  ...                    0   3
# 4   27          0  ...                    2   4
# 5   32          0  ...                    6   5
# 6   59          0  ...                    0   6
# 7   30          0  ...                    0   7
# 8   38          0  ...                    8   8
# 9   36          0  ...                    7   9
#
# [10 rows x 34 columns]

# %%
# Load movies.csv
url_movies = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Google_Colab_Notebooks/DataScience/L2/moviesData.csv"
movies = pd.read_csv(url_movies)

# Print the last ten rows of movies 
movies.tail(10)
# Out:
#      Unnamed: 0  ...            actor5
# 590         591  ...        Ben Vereen
# 591         592  ...       Bob Balaban
# 592         593  ...     George Gaynes
# 593         594  ...   Lance Henriksen
# 594         595  ...  Steve Guttenberg
# 595         596  ...       Jack Bailey
# 596         597  ...       Rachel True
# 597         598  ...    Randy McDowell
# 598         599  ...       Ian McNeice
# 599         600  ...    Adam G. Sevani
#
# [10 rows x 31 columns]

# %% [markdown]
# ---
# ## Part 2 - Drawing correlation and heatmap
# ---

# %% [markdown]
# ### Using the correlation matrix, peform the following:
#
# * Find the correlation matrix for the ```movies```.
# * Draw a **heatmap** with the correlation matrix and display the values of correlation coefficients for each pair of features. Make sure the values are properly visible. You might want to adjust the figure size for this.
# * Create a ```mask``` to remove the duplicate values from the **heatmap**.

# %%
# Find out the correlation matrix 
movies.corr()

# Draw the heatmap 
plt.figure(figsize=(15,15))
sns.heatmap(movies.corr(),annot=True)

# %%
# Creating a mask for removing duplicates 
plt.figure(figsize=(15,15))
mask = np.zeros_like(movies.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(movies.corr(),annot=True,mask=mask)

# %% [markdown]
# ---
# ## Part 3 - Drawing plots and customizing these
# ---

# %% [markdown]
# ### Using a histogram, peform the following:
#
# * Draw a histogram of all the numeric features in ```train```. Please note that this can be done in a single command.
#
# * Find out whether there is any redundant features in ```train```, which can be dropped while building a model.

# %%
# Draw a histogram 
train.info()
train.hist(figsize=(20,20))
# Find out the redundant features 
print("From the Histogram we find that the Following are the redundant features: Attrition,Employee Count,Performance rating")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028 entries, 0 to 1027
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1028 non-null   int64
#  1   Attrition                 1028 non-null   int64
#  2   BusinessTravel            1028 non-null   object
#  3   DailyRate                 1028 non-null   int64
#  4   Department                1028 non-null   object
#  5   DistanceFromHome          1028 non-null   int64
#  6   Education                 1028 non-null   int64
#  7   EducationField            1028 non-null   object
#  8   EmployeeCount             1028 non-null   int64
#  9   EmployeeNumber            1028 non-null   int64
#  10  EnvironmentSatisfaction   1028 non-null   int64
#  11  Gender                    1028 non-null   object
#  12  HourlyRate                1028 non-null   int64
#  13  JobInvolvement            1028 non-null   int64
#  14  JobLevel                  1028 non-null   int64
#  15  JobRole                   1028 non-null   object
#  16  JobSatisfaction           1028 non-null   int64
#  17  MaritalStatus             1028 non-null   object
#  18  MonthlyIncome             1028 non-null   int64
#  19  MonthlyRate               1028 non-null   int64
#  20  NumCompaniesWorked        1028 non-null   int64
#  21  OverTime                  1028 non-null   object
#  22  PercentSalaryHike         1028 non-null   int64
#  23  PerformanceRating         1028 non-null   int64
#  24  RelationshipSatisfaction  1028 non-null   int64
#  25  StockOptionLevel          1028 non-null   int64
#  26  TotalWorkingYears         1028 non-null   int64
#  27  TrainingTimesLastYear     1028 non-null   int64
#  28  WorkLifeBalance           1028 non-null   int64
#  29  YearsAtCompany            1028 non-null   int64
#  30  YearsInCurrentRole        1028 non-null   int64
#  31  YearsSinceLastPromotion   1028 non-null   int64
#  32  YearsWithCurrManager      1028 non-null   int64
#  33  ID                        1028 non-null   int64
# dtypes: int64(27), object(7)
# memory usage: 273.2+ KB
# From the Histogram we find that the Following are the redundant features: Attrition,Employee Count,Performance rating

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Draw a scatter plot between between ```imdb_rating``` and ```audience_score```, and also fit a regression line.
# * Change the color of marker to red, size to 200, transparency to 0.3.

# %%
# Scatter plot to fit the regression line 
sns.regplot(movies.imdb_rating,movies.audience_score,ci=95)

# %%
# Change marker of the scatter plot
sns.regplot(movies.imdb_rating,movies.audience_score,ci=95,marker='+',scatter_kws={"color":"red", "alpha":0.3, "s":200})

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw a scatter plot between between ```petal_length``` and ```petal_width``` and color it according to the ```species```.
# * Change the size of marker to 100 and place the legend in ```lower right```.

# %%
# library & dataset
df = sns.load_dataset('iris')
 
# Use the 'hue' argument to provide a factor variable
sns.lmplot('petal_length','petal_width',hue='species',legend=False,data=df,fit_reg=False,scatter_kws={"s":100})
 
# Move the legend to an empty part of the plot
plt.legend(loc='lower right')

# %% [markdown]
# ---
# ## Part 4 - Density Plots
# ---

# %% [markdown]
# ### Using density plots, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots for all the features ```sepal_width```, ```sepal_length```, ```petal_width```, and ```petal_length```. You can required to use subplots for plotting all the density plots.
# * Try drawing a [CDF](https://en.wikipedia.org/wiki/Cumulative_distribution_function) of these features. There is a [blog on medium](https://medium.com/@rishav.jnit/exploratory-data-analysis-eda-on-iris-dataset-using-python-cadd850c1fc6) on how to plot CDF. It will be covered in tutorial.

# %%
# library and dataset 
df = sns.load_dataset('iris')
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(2,2)
fig.suptitle("Density plots for various features of the Iris Data set",fontsize=12,color="Indigo")
sns.kdeplot(df['sepal_width'], shade=True, color="r",ax=ax1)
sns.kdeplot(df['sepal_length'], shade=True, color="b",ax=ax2)
sns.kdeplot(df['petal_width'], shade=True, color="g",ax=ax3)
sns.kdeplot(df['petal_length'],shade=True,color="y",ax=ax4)

# %%
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(2,2)
fig.suptitle("CDF plots for various features of the Iris Data set",fontsize=12,color="Maroon")
sns.kdeplot(df['sepal_width'], shade=True, color="r",ax=ax1,cumulative=True)
sns.kdeplot(df['sepal_length'], shade=True, color="b",ax=ax2,cumulative=True)
sns.kdeplot(df['petal_width'], shade=True, color="g",ax=ax3,cumulative=True)
sns.kdeplot(df['petal_length'],shade=True,color="y",ax=ax4,cumulative=True)

# %% [markdown]
# ### Using violin plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots of ```species``` versus ```sepal_length```.
# * Assign each group a color like
#
#     * versicolor - green,
#     * setosa - blue,
#     * virginica - m

# %%
#load the iris data set
sns.load_dataset('iris')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Draw the normal violin plots 
sns.violinplot(x=df["species"], y=df["sepal_length"])

# %%
# Change the color of each group 

sns.violinplot(x=df["species"], y=df["sepal_length"],palette=['b','g','m'])
