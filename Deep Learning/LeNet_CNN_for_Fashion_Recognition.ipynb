# %% [markdown]
# <a href="https://colab.research.google.com/github/kjyothiswaroop/LeNet-5-Architechture-/blob/master/LeNet_CNN_for_Fashion_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Fashion Recognition - LeNet CNN**#
#
# This file performs the Fashion Recognition on the Fashion-MNIST Data set. We use the Tensorflow framework to perform the following task.
#
# The Details regarding the LeNet Model can be found in the following Paper:
# http://vision.stanford.edu/cs598_spring07/papers/Lecun98.pdf
#
# The data set is already present in the tf.keras API.
# We will be performing the following steps on the data:
#
# 1) Loading and Preparing the Input Data.
#
# 2) Prepare the model by joining the layers of the model.
#
# 3)Training the Model with the train data by choosing an appropriate loss function.
#
# 4)Run the Model on the test data and check the accuracy.

# %%
#Import the Required Libraries
import tensorflow as tf
import numpy as np

print(tf.__version__)
# Out:
# 2.2.0

# %%
#Loading the Data
print("Downloading Data .......")
fashionmnist = tf.keras.datasets.fashion_mnist
(x_train,y_train) , (x_test, y_test) = fashionmnist.load_data()
# Out:
# Downloading Data .......
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
#Preparing the Data
num_categories = 10
image_width = 28
image_height = 28
image_channels = 1
class_names =['T-shirt/Top','Trouser','Pullover','Dress','Coat/Jacket','Sandal','Shirt','Sneaker','Bag','Ankle Boot']

# %%
x_train = x_train.reshape(x_train.shape[0],image_width,image_height,image_channels)
x_test = x_test.reshape(x_test.shape[0],image_width,image_height,image_channels)

# %%
x_train = x_train.astype('float32')/255.0
x_test = x_test.astype('float32')/255.0

# %%
#import the required libraries
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras import backend
# Preparing The Model
## INPUt--CONV--Activation--Pooling--CONV--Activation--Pooling--FC--activation--FC--activation--FC--lossfunction
#LeNet 5 uses Tanh as activation, also a slight change we are making is that we are using Softmax as loss function
class LeNet:
  def init(image_channels,image_width,image_height,num_categories,weightsPath=None):
    if backend.image_data_format() == "channels_first" :
       inputShape = (image_channels,image_width,image_height)
    else :
       inputShape = (image_width,image_height,image_channels)
   
   #Initialise the Model
    model = models.Sequential()
   #add the first layer
    model.add(layers.Conv2D(filters=6,kernel_size=(5,5),strides=(1,1),padding='valid',activation = tf.nn.tanh,input_shape = inputShape))
    model.add(layers.AveragePooling2D(pool_size=(2,2), strides=(2,2)))
   #Second Layer
    model.add(layers.Conv2D(filters=16,kernel_size=(5,5),strides=(1,1),padding='valid',activation = tf.nn.tanh,input_shape = inputShape))
    model.add(layers.AveragePooling2D(pool_size=(2,2), strides=(2,2)))
   #Flatten the layers so that they can be fed to the dense layers
    model.add(layers.Flatten())
   #Add the Dense Layer 1
    model.add(layers.Dense(units=120,activation=tf.nn.tanh))
   #Add the Dense Layer 2
    model.add(layers.Dense(units=84,activation=tf.nn.tanh))
   #Now let us finally Add the Softmax Layer
    model.add(layers.Dense(units=num_categories,activation=tf.nn.softmax))
   #For the Purpose of Transfer Learning if we already have weight we supply them for the purpose of Training
    if weightsPath is not None:
       model.load_weights(weightsPath)
    return model

# %%
#Compile the Model
print('Compiling........')
model = LeNet.init(image_channels=1,image_width=28,image_height=28,num_categories=10,weightsPath=None)
model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.01),loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Compiling........
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 24, 24, 6)         156
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 12, 12, 6)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 16)          2416
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 4, 4, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 120)               30840
# _________________________________________________________________
# dense_4 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                850
# =================================================================
# Total params: 44,426
# Trainable params: 44,426
# Non-trainable params: 0
# _________________________________________________________________

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self,epoch,logs=None):
      if(logs.get('accuracy')>0.95):
         self.model.stop_training = True
#Train the Model
batch_size = 128
epochs = 100
#run the model
history = model.fit(x=x_train,y=y_train, validation_data = (x_test,y_test),batch_size = batch_size, epochs=epochs,verbose=1,callbacks=[myCallback()])
# Out:
# Epoch 1/100
# 469/469 [==============================] - 3s 6ms/step - loss: 1.3348 - accuracy: 0.5720 - val_loss: 0.8799 - val_accuracy: 0.6918
# Epoch 2/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.7701 - accuracy: 0.7193 - val_loss: 0.7254 - val_accuracy: 0.7246
# Epoch 3/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.6691 - accuracy: 0.7473 - val_loss: 0.6609 - val_accuracy: 0.7489
# Epoch 4/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.6177 - accuracy: 0.7676 - val_loss: 0.6216 - val_accuracy: 0.7650
# Epoch 5/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.5839 - accuracy: 0.7812 - val_loss: 0.5942 - val_accuracy: 0.7789
# Epoch 6/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.5585 - accuracy: 0.7930 - val_loss: 0.5739 - val_accuracy: 0.7872
# Epoch 7/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.5385 - accuracy: 0.8004 - val_loss: 0.5554 - val_accuracy: 0.7914
# Epoch 8/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.5222 - accuracy: 0.8069 - val_loss: 0.5416 - val_accuracy: 0.8014
# Epoch 9/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.5083 - accuracy: 0.8118 - val_loss: 0.5283 - val_accuracy: 0.8037
# Epoch 10/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4965 - accuracy: 0.8169 - val_loss: 0.5173 - val_accuracy: 0.8086
# Epoch 11/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4860 - accuracy: 0.8215 - val_loss: 0.5101 - val_accuracy: 0.8103
# Epoch 12/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4763 - accuracy: 0.8250 - val_loss: 0.4982 - val_accuracy: 0.8188
# Epoch 13/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4673 - accuracy: 0.8293 - val_loss: 0.4908 - val_accuracy: 0.8224
# Epoch 14/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4591 - accuracy: 0.8328 - val_loss: 0.4825 - val_accuracy: 0.8265
# Epoch 15/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4514 - accuracy: 0.8366 - val_loss: 0.4776 - val_accuracy: 0.8306
# Epoch 16/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4444 - accuracy: 0.8391 - val_loss: 0.4696 - val_accuracy: 0.8330
# Epoch 17/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4378 - accuracy: 0.8425 - val_loss: 0.4628 - val_accuracy: 0.8320
# Epoch 18/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4309 - accuracy: 0.8455 - val_loss: 0.4559 - val_accuracy: 0.8382
# Epoch 19/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4252 - accuracy: 0.8473 - val_loss: 0.4518 - val_accuracy: 0.8393
# Epoch 20/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4195 - accuracy: 0.8495 - val_loss: 0.4466 - val_accuracy: 0.8428
# Epoch 21/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4141 - accuracy: 0.8521 - val_loss: 0.4423 - val_accuracy: 0.8417
# Epoch 22/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4091 - accuracy: 0.8542 - val_loss: 0.4412 - val_accuracy: 0.8434
# Epoch 23/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4045 - accuracy: 0.8544 - val_loss: 0.4364 - val_accuracy: 0.8462
# Epoch 24/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4001 - accuracy: 0.8563 - val_loss: 0.4302 - val_accuracy: 0.8486
# Epoch 25/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3957 - accuracy: 0.8590 - val_loss: 0.4253 - val_accuracy: 0.8502
# Epoch 26/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3917 - accuracy: 0.8599 - val_loss: 0.4226 - val_accuracy: 0.8517
# Epoch 27/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3878 - accuracy: 0.8609 - val_loss: 0.4166 - val_accuracy: 0.8508
# Epoch 28/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3840 - accuracy: 0.8626 - val_loss: 0.4151 - val_accuracy: 0.8514
# Epoch 29/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3814 - accuracy: 0.8636 - val_loss: 0.4119 - val_accuracy: 0.8503
# Epoch 30/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3772 - accuracy: 0.8643 - val_loss: 0.4085 - val_accuracy: 0.8534
# Epoch 31/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3743 - accuracy: 0.8660 - val_loss: 0.4059 - val_accuracy: 0.8552
# Epoch 32/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3711 - accuracy: 0.8671 - val_loss: 0.4023 - val_accuracy: 0.8567
# Epoch 33/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3680 - accuracy: 0.8673 - val_loss: 0.4004 - val_accuracy: 0.8549
# Epoch 34/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3650 - accuracy: 0.8696 - val_loss: 0.3952 - val_accuracy: 0.8576
# Epoch 35/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3625 - accuracy: 0.8703 - val_loss: 0.3984 - val_accuracy: 0.8547
# Epoch 36/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3598 - accuracy: 0.8712 - val_loss: 0.3943 - val_accuracy: 0.8568
# Epoch 37/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3574 - accuracy: 0.8712 - val_loss: 0.3873 - val_accuracy: 0.8600
# Epoch 38/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3547 - accuracy: 0.8728 - val_loss: 0.3895 - val_accuracy: 0.8596
# Epoch 39/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3523 - accuracy: 0.8732 - val_loss: 0.3872 - val_accuracy: 0.8601
# Epoch 40/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3503 - accuracy: 0.8739 - val_loss: 0.3884 - val_accuracy: 0.8588
# Epoch 41/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3482 - accuracy: 0.8752 - val_loss: 0.3797 - val_accuracy: 0.8646
# Epoch 42/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3460 - accuracy: 0.8758 - val_loss: 0.3784 - val_accuracy: 0.8653
# Epoch 43/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3436 - accuracy: 0.8761 - val_loss: 0.3786 - val_accuracy: 0.8619
# Epoch 44/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3416 - accuracy: 0.8768 - val_loss: 0.3821 - val_accuracy: 0.8610
# Epoch 45/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3390 - accuracy: 0.8781 - val_loss: 0.3779 - val_accuracy: 0.8623
# Epoch 46/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3377 - accuracy: 0.8788 - val_loss: 0.3735 - val_accuracy: 0.8646
# Epoch 47/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3355 - accuracy: 0.8795 - val_loss: 0.3722 - val_accuracy: 0.8659
# Epoch 48/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3332 - accuracy: 0.8802 - val_loss: 0.3700 - val_accuracy: 0.8678
# Epoch 49/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3316 - accuracy: 0.8814 - val_loss: 0.3722 - val_accuracy: 0.8637
# Epoch 50/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3302 - accuracy: 0.8810 - val_loss: 0.3658 - val_accuracy: 0.8677
# Epoch 51/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3278 - accuracy: 0.8820 - val_loss: 0.3633 - val_accuracy: 0.8682
# Epoch 52/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3261 - accuracy: 0.8832 - val_loss: 0.3685 - val_accuracy: 0.8681
# Epoch 53/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3248 - accuracy: 0.8827 - val_loss: 0.3613 - val_accuracy: 0.8673
# Epoch 54/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3228 - accuracy: 0.8839 - val_loss: 0.3587 - val_accuracy: 0.8713
# Epoch 55/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3212 - accuracy: 0.8848 - val_loss: 0.3641 - val_accuracy: 0.8680
# Epoch 56/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3195 - accuracy: 0.8852 - val_loss: 0.3559 - val_accuracy: 0.8708
# Epoch 57/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3179 - accuracy: 0.8862 - val_loss: 0.3576 - val_accuracy: 0.8700
# Epoch 58/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3162 - accuracy: 0.8856 - val_loss: 0.3548 - val_accuracy: 0.8724
# Epoch 59/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3151 - accuracy: 0.8865 - val_loss: 0.3524 - val_accuracy: 0.8743
# Epoch 60/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3133 - accuracy: 0.8863 - val_loss: 0.3505 - val_accuracy: 0.8740
# Epoch 61/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3116 - accuracy: 0.8882 - val_loss: 0.3505 - val_accuracy: 0.8739
# Epoch 62/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3097 - accuracy: 0.8885 - val_loss: 0.3496 - val_accuracy: 0.8724
# Epoch 63/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3090 - accuracy: 0.8889 - val_loss: 0.3522 - val_accuracy: 0.8699
# Epoch 64/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3077 - accuracy: 0.8889 - val_loss: 0.3456 - val_accuracy: 0.8754
# Epoch 65/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3058 - accuracy: 0.8898 - val_loss: 0.3448 - val_accuracy: 0.8743
# Epoch 66/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3046 - accuracy: 0.8906 - val_loss: 0.3491 - val_accuracy: 0.8753
# Epoch 67/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3031 - accuracy: 0.8907 - val_loss: 0.3473 - val_accuracy: 0.8743
# Epoch 68/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3019 - accuracy: 0.8913 - val_loss: 0.3439 - val_accuracy: 0.8720
# Epoch 69/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3006 - accuracy: 0.8921 - val_loss: 0.3418 - val_accuracy: 0.8769
# Epoch 70/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2992 - accuracy: 0.8926 - val_loss: 0.3425 - val_accuracy: 0.8741
# Epoch 71/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2983 - accuracy: 0.8926 - val_loss: 0.3423 - val_accuracy: 0.8737
# Epoch 72/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2969 - accuracy: 0.8927 - val_loss: 0.3384 - val_accuracy: 0.8790
# Epoch 73/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2954 - accuracy: 0.8932 - val_loss: 0.3363 - val_accuracy: 0.8799
# Epoch 74/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2945 - accuracy: 0.8937 - val_loss: 0.3356 - val_accuracy: 0.8791
# Epoch 75/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2929 - accuracy: 0.8945 - val_loss: 0.3351 - val_accuracy: 0.8796
# Epoch 76/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2920 - accuracy: 0.8948 - val_loss: 0.3373 - val_accuracy: 0.8790
# Epoch 77/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2907 - accuracy: 0.8949 - val_loss: 0.3345 - val_accuracy: 0.8810
# Epoch 78/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2891 - accuracy: 0.8960 - val_loss: 0.3350 - val_accuracy: 0.8778
# Epoch 79/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2878 - accuracy: 0.8956 - val_loss: 0.3329 - val_accuracy: 0.8792
# Epoch 80/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2873 - accuracy: 0.8966 - val_loss: 0.3306 - val_accuracy: 0.8796
# Epoch 81/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2858 - accuracy: 0.8966 - val_loss: 0.3336 - val_accuracy: 0.8789
# Epoch 82/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2846 - accuracy: 0.8975 - val_loss: 0.3468 - val_accuracy: 0.8716
# Epoch 83/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2840 - accuracy: 0.8977 - val_loss: 0.3282 - val_accuracy: 0.8818
# Epoch 84/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2826 - accuracy: 0.8979 - val_loss: 0.3325 - val_accuracy: 0.8785
# Epoch 85/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2814 - accuracy: 0.8992 - val_loss: 0.3329 - val_accuracy: 0.8773
# Epoch 86/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2808 - accuracy: 0.8988 - val_loss: 0.3282 - val_accuracy: 0.8828
# Epoch 87/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2799 - accuracy: 0.8990 - val_loss: 0.3265 - val_accuracy: 0.8824
# Epoch 88/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2783 - accuracy: 0.8997 - val_loss: 0.3263 - val_accuracy: 0.8817
# Epoch 89/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2773 - accuracy: 0.8997 - val_loss: 0.3272 - val_accuracy: 0.8818
# Epoch 90/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2762 - accuracy: 0.8994 - val_loss: 0.3267 - val_accuracy: 0.8849
# Epoch 91/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2757 - accuracy: 0.9001 - val_loss: 0.3230 - val_accuracy: 0.8848
# Epoch 92/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2743 - accuracy: 0.9008 - val_loss: 0.3216 - val_accuracy: 0.8853
# Epoch 93/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2735 - accuracy: 0.9020 - val_loss: 0.3203 - val_accuracy: 0.8849
# Epoch 94/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2722 - accuracy: 0.9018 - val_loss: 0.3233 - val_accuracy: 0.8825
# Epoch 95/100
# 469/469 [==============================] - 3s 5ms/step - loss: 0.2719 - accuracy: 0.9017 - val_loss: 0.3214 - val_accuracy: 0.8837
# Epoch 96/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2708 - accuracy: 0.9013 - val_loss: 0.3210 - val_accuracy: 0.8840
# Epoch 97/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2693 - accuracy: 0.9033 - val_loss: 0.3275 - val_accuracy: 0.8814
# Epoch 98/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2693 - accuracy: 0.9027 - val_loss: 0.3256 - val_accuracy: 0.8822
# Epoch 99/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2680 - accuracy: 0.9028 - val_loss: 0.3278 - val_accuracy: 0.8816
# Epoch 100/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2668 - accuracy: 0.9029 - val_loss: 0.3172 - val_accuracy: 0.8861

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_accuarcy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))
plt.plot(epochs,acc, label='Training Accuracy')
plt.plot(epochs,val_accuarcy,label='Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Trainig and validation Accuracies')
plt.figure()

plt.plot(epochs,loss, label='Training Loss')
plt.plot(epochs,val_loss,label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Trainig and validation losses')
plt.figure()

# %%
#Evaluating
(loss,accuracy) = model.evaluate(x_test,y_test,batch_size=batch_size,verbose=1)
print("accuracy:{:.2f}%".format(accuracy*100))
# Out:
# 79/79 [==============================] - 0s 3ms/step - loss: 0.3172 - accuracy: 0.8861
# accuracy:88.61%

# %% [markdown]
# #Regenerating the Images and their Predictions#
# The Below code helps in regenerating the images and their labels.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
nrows = 3
ncols = 4
fig = plt.gcf()
fig.set_size_inches(ncols*4,nrows*4)
num_predictions = 12
test_indices = np.random.choice(np.arange(0,len(y_test)),size = (num_predictions, ))
test_images = np.stack(([x_test[i] for i in test_indices]))
test_labels = np.stack(([y_test[i] for i in test_indices]))
predictions = model.predict(x_test)
for i in range(num_predictions):
   prediction = np.argmax(predictions[i])
   image = (x_test[i]*255).astype("uint8")
   image = cv2.resize(image , (96,96),interpolation=cv2.INTER_CUBIC)
   image = cv2.merge([image]*3)
   if prediction == y_test[i]:
      rgb_color = (0,255,0)
   else:
      rgb_color = (255,0,0)
   cv2.putText(image,str(class_names[prediction]),(0,10),cv2.FONT_HERSHEY_SIMPLEX,0.5,rgb_color,1)
   sp = plt.subplot(nrows,ncols,i+1,title="label: %s" % class_names[y_test[i]])
   sp.axis("Off")
   plt.imshow(image)
plt.show()
